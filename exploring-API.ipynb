# %% [markdown]
# ## Exploring Unsplash API

# %%
import requests

# %%
api_response = requests.get('https://api.openweathermap.org/data/2.5/weather?lat=44.32&lon=10.98&appid=75888166353b3bceb007d3f435676c70')

# %%
api_response.status_code
# Out:
# 200

# %%
data = api_response.json()
# data

# %%
data.keys()
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
data['weather']
# Out:
# [{'id': 802,
#   'main': 'Clouds',
#   'description': 'scattered clouds',
#   'icon': '03n'}]

# %%
data['weather'][0]['icon']
# Out:
# '03n'
